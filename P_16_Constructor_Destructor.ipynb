# %%
# Constructor & Destructor

# In this file we will study constructor,destructor,decorator (add on)

# CONSTRUCTOR

# 1.It is a special method within a class that
# gets automatically called when an object is created.
# 2.It is used to initialize the attributes of the object.
# 3.It is written with __init__
# 4 There are two types of constructors:
# a. Default constructors.
# It does not accept any arguments from the object and
# has only one argument name i.e.  self.
# b. Parameterized constructors ( takes more than one argument along with self


# SOURCE (Geeksforgeeks.org)


# EXAMPLE (add on)

class Plane:
     def __init__(self):
         self.wings = 2

         # fly
         self.drive()
         self.flaps()
         self.wheels()

     def drive(self):
             print('Accelerating')
     def flaps(self):
         
             print('Changing flaps')

     def wheels(self):
             print('Closing wheels')

 obj = Plane()


# DESTRUCTOR

# 1. Destructor in Python is called when an object gets destroyed.(add on)
# 2. Destructors are used to destroy the object’s state.
# 3. It is written as __del__

# EXAMPLE (add on)

\class A(object):

     def __init__(self):    # constructor
         self.str1 = 'PrepInsta'

         print('Object_Created', self.str1)

     def __del__(self):    # destructor
         print('Destructor is called Manually')



ob = A()
del ob
 ob = A()

# DECORATORS (add on)

# 1. Decorator is a function that takes another
# function as argument and returns a function.
# 2. Returns a new function that modify the
# behaviour of the original function.
# 3. It is written as '@'


# EXAMPLE (add on)

def uppercase(func):
     def wrapper(*args, **kwargs):
         return func(*args, **kwargs).upper()

     return wrapper


 @uppercase
 def greet(name):
     return f"Hello, {name}!"


 print(greet("Bob"))





# simple program

class Demo:
    def __init__(self):
        print("Constructor called")

    def __del__(self):
        print("Destructor called")

obj = Demo()

# Decorator example
def decorator(func):
    def wrapper():
        print("Before function")
        func()
        print("After function")
    return wrapper

@decorator
def say_hello():
    print("Hello!")

say_hello()

# %% [markdown]
# # Constructor & Destructor
#
# # In this file we will study constructor,destructor,decorator (add on)
#
# # CONSTRUCTOR
#
# # 1.It is a special method within a class that
# # gets automatically called when an object is created.
# # 2.It is used to initialize the attributes of the object.
# # 3.It is written with __init__
# # 4 There are two types of constructors:
# # a. Default constructors.
# # It does not accept any arguments from the object and
# # has only one argument name i.e.  self.
# # b. Parameterized constructors ( takes more than one argument along with self

# %%
class Plane:
     def __init__(self):
         self.wings = 2

         # fly
         self.drive()
         self.flaps()
         self.wheels()
     def drive(self):
             print('Accelerating')

     def flaps(self):
             print('Changing flaps')

     def wheels(self):
             print('Closing wheels')

obj = Plane()
# Out:
# Accelerating
# Changing flaps
# Closing wheels

# %% [markdown]
# # DESTRUCTOR
#
# # 1. Destructor in Python is called when an object gets destroyed.(add on)
# # 2. Destructors are used to destroy the object’s state.
# # 3. It is written as __del_

# %%
# EXAMPLE (add on)

class A(object):

     def __init__(self):    # constructor
         self.str1 = 'PrepInsta'

         print('Object_Created', self.str1)

     def __del__(self):    # destructor
         print('Destructor is called Manually')



ob = A()
del ob
ob = A()
# Out:
# Object_Created PrepInsta
# Destructor is called Manually
# Object_Created PrepInsta

# %% [markdown]
# # DECORATORS (add on)
#
# # 1. Decorator is a function that takes another
# # function as argument and returns a function.
# # 2. Returns a new function that modify the
# # behaviour of the original function.
# # 3. It is written as '@'

# %%
# EXAMPLE (add on)

def uppercase(func):
     def wrapper(*args, **kwargs):
         return func(*args, **kwargs).upper()

     return wrapper


@uppercase
def greet(name):
     return f"Hello, {name}!"


print(greet("Bob"))
# Out:
# HELLO, BOB!

# %%
# simple program

class Demo:
    def __init__(self):
        print("Constructor called")

    def __del__(self):
        print("Destructor called")

obj = Demo()

# Decorator example
def decorator(func):
    def wrapper():
        print("Before function")
        func()
        print("After function")
    return wrapper

@decorator
def say_hello():
    print("Hello!")

say_hello()
# Out:
# Constructor called
# Before function
# Hello!
# After function
